# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайтов Superjob и HH.
#
# Приложение должно анализировать несколько страниц сайта (также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
# Наименование вакансии.
#
# Предлагаемую зарплату (отдельно минимальную и максимальную).
#
# Ссылку на саму вакансию.
#
# Сайт, откуда собрана вакансия.
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
def parser_superjob(vacancy):

    vacancy_info = []

    params = {
        'keywords': vacancy,
        'page': ''
    }

    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'
    }

    url = 'https://www.superjob.ru/vacancy/search/'

    response = requests.get(url, params=params, headers=headers)

    soup = bs(response.text, 'lxml')

    page_block = soup.find('a', {'class': 'f-test-button-1'})

    if not page_block:
        last_page = 1
    else:
        page_block = page_block.findParent()
        last_page = int(page_block.find_all('a')[-2].getText())

    for page in range(0, last_page + 1):
        params['page'] = page
        html = requests.get(url, params=params, headers=headers)

    soup = bs(html.text, 'lxml')

    vacancy_items = soup.find_all('div', {'class': 'f-test-vacancy-item'})

    for item in vacancy_items:
        vacancy_info.append(item_superjob(item))

    return vacancy_info

# %%
def item_superjob(item):

    vacancy_info = {}

    vacancy_name = item.find('a').getText()

    vacancy_info['vacancy_name'] = vacancy_name

    company_name = item.find('span', {'class': 'f-test-text-vacancy-item-company-name'})

    if not company_name:
        company_name = item.findParent().find('span', {'class': 'f-test-text-vacancy-item-company-name'}).getText()
    else:
        company_name = company_name.getText()

    vacancy_info['company_name'] = company_name

    vacancy_city = item.find('span', {'class': 'f-test-text-company-item-location'}).findChildren()[2].getText().split(',')

    vacancy_info['vacancy_city'] = vacancy_city[0]

    salary = item.find('span', {'class': 'f-test-text-company-item-salary'}).getText()

    if not salary or salary == 'По договорённости':
        salary_min = None
        salary_max = None
        salary_currency = None

    else:

        salary_split = salary.replace(u'\xa0', u' ').split(' ')
        salary_currency = salary_split[-1]

        if salary_split[0] == 'до':
            salary_min = None
            salary_max = int(salary_split[1] + salary_split[2])
        elif salary_split[0] == 'от':
            salary_min = int(salary_split[1] + salary_split[2])
            salary_max = None
        else:
            salary_min = int(salary_split[0] + salary_split[1])
            salary_max = int(salary_split[-3] + salary_split[-2])

    vacancy_info['salary_min'] = salary_min
    vacancy_info['salary_max'] = salary_max
    vacancy_info['salary_currency'] = salary_currency

    vacancy_url = item.find_all('a')

    if len(vacancy_url) > 1:
        vacancy_url = vacancy_url[-2]['href']
    else:
        vacancy_url = vacancy_url[0]['href']

    vacancy_info['vacancy_url'] = f'https://www.superjob.ru{vacancy_url}'

    vacancy_info['site'] = 'www.superjob.ru'

    return vacancy_info

# %%
def parser_hh(vacancy):

    url = 'https://hh.ru/search/vacancy'
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'
    }
    
    params = {
        'text': vacancy,
        'search_field': 'name',
        'items_on_page': '100',
        'page': ''
    }
    
    response = requests.get(url, params=params, headers=headers)
    soup = bs(response.text, 'lxml')
    
    vacancy_info = []
    
    page_block = soup.find('div', {'data-qa': 'pager-block'})
    
    if not page_block:
        last_page = '1'
    else:
        last_page = int(page_block.find_all('a', {'class': 'HH-Pager-Control'})[-2].getText())
    
    for page in range(0, last_page):
        params['page'] = page
        html = requests.get(url, params=params, headers=headers)
    
    soup = bs(html.text, 'lxml')
    
    vacancy_items = soup.find('div', {'data-qa': 'vacancy-serp__results'}).find_all('div', {'class': 'vacancy-serp-item'})
    
    for item in vacancy_items:
        vacancy_info.append(item_hh(item))

    return vacancy_info

# %%
def item_hh(item):

    vacancy_info = {}

    vacancy_name = item.find('span', {'class': 'resume-search-item__name'}).getText().replace(u'\xa0', u' ')

    vacancy_info['vacancy_name'] = vacancy_name

    company_name = item.find('div', {'class': 'vacancy-serp-item__meta-info'}).find('a').getText()

    vacancy_info['company_name'] = company_name

    vacancy_city = item.find('span', {'class': 'vacancy-serp-item__meta-info'}).getText().split(', ')[0]

    vacancy_info['vacancy_city'] = vacancy_city

    salary = item.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'})
    if not salary:
        salary_min = None
        salary_max = None
        salary_currency = None
    else:
        salary = salary.getText().replace(u'\xa0', u'')

        salary = re.split(r'\s|-', salary)

        if salary[0] == 'до':
            salary_min = None
            salary_max = int(salary[1])
        elif salary[0] == 'от':
            salary_min = int(salary[1])
            salary_max = None
        else:
            salary_min = int(salary[0])
            salary_max = int(salary[-2])

        salary_currency = salary[-1]

    vacancy_info['salary_min'] = salary_min
    vacancy_info['salary_max'] = salary_max
    vacancy_info['salary_currency'] = salary_currency


    vacancy_url = item.find('span', {'class': 'resume-search-item__name'}).find('a')['href']

    vacancy_info['vacancy_url'] = vacancy_url[:vacancy_url.find('?')]

    vacancy_info['site'] = 'hh.ru'

    return vacancy_info

# %%
def parser_vacancy(vacancy):
        
    vacancy_info = []
    vacancy_info.extend(parser_hh(vacancy))
    vacancy_info.extend(parser_superjob(vacancy))
    
    df = pd.DataFrame(vacancy_info)

    return df

# %%
vacancy = 'Python'
df = parser_vacancy(vacancy)

# %%
df[:100]
# Out:
#                                          company_name salary_currency  \
# 0                                       АО Консист-ОС            None
# 1                                        ПАО «МТС»,IT            None
# 2    Центр компьютерного обучения СПЕЦИАЛИСТ при М...            руб.
# 3                                           ООО ЦИФРА            None
# 4                                    ООО Кловер Групп            None
# 5                        Recruitment Boutique S.M.Art            None
# 6                                        ЗАО Научсофт            None
# 7                              Сбербанк для экспертов            None
# 8                      ИП Бутаков Анатолий Николаевич            руб.
# 9                                            Тинькофф            None
# 10                                   Top Selection OÜ            None
# 11                                   Top Selection OÜ            None
# 12                                           Forecsys            None
# 13                                    ООО Тагес Джамп            руб.
# 14                                           DataData            руб.
# 15                                    ООО Тагес Джамп            руб.
# 16                         Институт Бизнес-Технологий            None
# 17                                         ООО Тензор            руб.
# 18                                         ООО Тензор            руб.
# 19                                             Яндекс            None
# 20                                          ООО СМАСС            None
# 21                                            JCat.ru            None
# 22                                          ДАТАДВАНС            None
# 23                                          ДАТАДВАНС            None
# 24                                          ДАТАДВАНС            None
# 25                                       ООО Мильжикс            None
# 26                                Центр Агроаналитики            руб.
# 27                             ООО Авгуро Технолоджис            руб.
# 28                                       ПАО «МТС»,IT            None
# 29                                              ОНСЕК            None
# ..                                                ...             ...
# 31                              Университет Иннополис            руб.
# 32                              Университет Иннополис            руб.
# 33              ГБУ Агентство Инноваций Города Москвы            None
# 34            ООО ШАГ, Компьютерная Академия (Одесса)            None
# 35                                         LeadBazaar            None
# 36                                 Группа «Кронштадт»            None
# 37                                      ООО АппФоллоу            None
# 38                                      ООО АппФоллоу            None
# 39                                            Qencode            грн.
# 40                                  ООО Дионис, Пенза            руб.
# 41                                         Альфа-Банк            None
# 42                                  Тройнов Александр             USD
# 43                                  Тройнов Александр             USD
# 44                                  Тройнов Александр             USD
# 45                                  Тройнов Александр             USD
# 46                                    ООО ТД Технодар            руб.
# 47                                ООО РН-БашНИПИнефть            None
# 48                                    ООО Гора Студио            руб.
# 49                                         ООО Аистэм            None
# 50                                          Flocktory            None
# 51                                           ООО ГТМК            руб.
# 52                                          Мегаполис            None
# 53                                            МФТИ ГУ            None
# 54                              "Концерн "Калашников"            None
# 55                                   РОСГОССТРАХ Банк            None
# 56  Центр стратегического планирования медико-биол...            руб.
# 57                                            МФТИ ГУ            None
# 58                                               МФТИ            руб.
# 59                                               МФТИ            руб.
# 60  ФГБУ Центр стратегического планирования медико...            None
#
#     salary_max  salary_min             site     vacancy_city  \
# 0          NaN         NaN            hh.ru           Москва
# 1          NaN         NaN            hh.ru           Москва
# 2          NaN    150000.0            hh.ru           Москва
# 3          NaN         NaN            hh.ru           Москва
# 4          NaN         NaN            hh.ru           Казань
# 5          NaN         NaN            hh.ru           Москва
# 6          NaN         NaN            hh.ru            Минск
# 7          NaN         NaN            hh.ru           Москва
# 8      80000.0     30000.0            hh.ru  Санкт-Петербург
# 9          NaN         NaN            hh.ru           Москва
# 10         NaN         NaN            hh.ru           Москва
# 11         NaN         NaN            hh.ru  Санкт-Петербург
# 12         NaN         NaN            hh.ru           Москва
# 13    100000.0         NaN            hh.ru        Краснодар
# 14    120000.0     70000.0            hh.ru     Екатеринбург
# 15    100000.0         NaN            hh.ru              Уфа
# 16         NaN         NaN            hh.ru            Минск
# 17    245000.0    160000.0            hh.ru      Новосибирск
# 18    245000.0    160000.0            hh.ru        Ярославль
# 19         NaN         NaN            hh.ru           Москва
# 20         NaN         NaN            hh.ru           Самара
# 21         NaN         NaN            hh.ru           Москва
# 22         NaN         NaN            hh.ru     Екатеринбург
# 23         NaN         NaN            hh.ru  Нижний Новгород
# 24         NaN         NaN            hh.ru      Новосибирск
# 25         NaN         NaN            hh.ru            Минск
# 26    140000.0    100000.0            hh.ru           Москва
# 27    140000.0         NaN            hh.ru     Екатеринбург
# 28         NaN         NaN            hh.ru           Москва
# 29         NaN         NaN            hh.ru           Москва
# ..         ...         ...              ...              ...
# 31    120000.0     80000.0            hh.ru           Казань
# 32    120000.0     80000.0            hh.ru  Санкт-Петербург
# 33         NaN         NaN            hh.ru           Москва
# 34         NaN         NaN            hh.ru           Одесса
# 35         NaN         NaN            hh.ru           Москва
# 36         NaN         NaN            hh.ru  Санкт-Петербург
# 37         NaN         NaN            hh.ru           Москва
# 38         NaN         NaN            hh.ru      Новосибирск
# 39     70000.0         NaN            hh.ru             Киев
# 40     60000.0     40000.0            hh.ru            Пенза
# 41         NaN         NaN            hh.ru        Ульяновск
# 42       500.0       500.0            hh.ru             Киев
# 43       500.0       500.0            hh.ru      Новосибирск
# 44       500.0       500.0            hh.ru  Санкт-Петербург
# 45       500.0       500.0            hh.ru           Казань
# 46     75000.0     45000.0            hh.ru     Петрозаводск
# 47         NaN         NaN            hh.ru              Уфа
# 48     90000.0     50000.0            hh.ru  Санкт-Петербург
# 49         NaN         NaN            hh.ru           Москва
# 50         NaN         NaN            hh.ru           Москва
# 51    100000.0         NaN            hh.ru        Волгоград
# 52         NaN         NaN  www.superjob.ru           Москва
# 53         NaN         NaN  www.superjob.ru           Москва
# 54         NaN         NaN  www.superjob.ru           Москва
# 55         NaN         NaN  www.superjob.ru           Москва
# 56         NaN    150000.0  www.superjob.ru           Москва
# 57         NaN         NaN  www.superjob.ru           Москва
# 58         NaN    120000.0  www.superjob.ru           Москва
# 59         NaN    120000.0  www.superjob.ru           Москва
# 60         NaN         NaN  www.superjob.ru           Москва
#
#                                          vacancy_name  \
# 0                             Разработчик JAVA/Python
# 1                                  Python разработчик
# 2   Преподаватель Python & Data Science и Machine ...
# 3                   Python Senior Developer Team Lead
# 4                                    Python developer
# 5   Backend разработчик Python/возможно удаленно (...
# 6                      Middle/Senior Python developer
# 7                                  Python разработчик
# 8   Преподаватель Python для детей в школу програм...
# 9                  Старший инженер-разработчик Python
# 10                         Python Developer (Backend)
# 11                         Python Developer (Backend)
# 12                           Разработчик (C#, Python)
# 13  Middle Python back-end / Golang Developer (Кра...
# 14                                 Программист Python
# 15  Middle Python / Golang / Js (node.js)/ Fullsta...
# 16      Преподаватель курса "Программирование Python"
# 17                         Ведущий Python разработчик
# 18                         Ведущий программист Python
# 19                                 Python разработчик
# 20                                Python/GO developer
# 21                                 Python-разработчик
# 22                                   Python developer
# 23                                   Python developer
# 24                                   Python developer
# 25                     Middle Python/Django Developer
# 26                                 Разработчик Python
# 27                         Python Backend-разработчик
# 28                                 Разработчик Python
# 29                                 Программист Python
# ..                                                ...
# 31                  Разработчик Python (г. Иннополис)
# 32                  Разработчик Python (г. Иннополис)
# 33                 Python/Django разработчик (Middle)
# 34  Преподаватель по курсу "Создание web-приложени...
# 35                      Backend-разработчик на Python
# 36        Senior/ Lead Python Developer (web-service)
# 37  Middle/Senior Python Backend Developer (Remote...
# 38  Middle/Senior Python Backend Developer (Remote...
# 39  Full Stack Engineer / Web Developer (PHP, Python)
# 40                  Fullstack разработчик (Python 3+)
# 41                                 Python-разработчик
# 42                   Python разработчик / Программист
# 43                   Python разработчик / программист
# 44                   Python разработчик / программист
# 45                   Python разработчик / программист
# 46                                 Программист Python
# 47                Python-разработчик (middle, senior)
# 48                 Python developer (computer vision)
# 49                            Преподаватель по Python
# 50                  Python developer / data scientist
# 51                                 Программист Python
# 52                                 Внутренний аудитор
# 53                                 Инженер-испытатель
# 54                    Ведущий системный администратор
